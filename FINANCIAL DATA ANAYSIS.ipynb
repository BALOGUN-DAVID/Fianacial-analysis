# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
financial_data = pd.read_csv("Riby Data Set.csv")
financial_data
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
financial_data.shape
# Out:
# (500000, 14)

# %%
financial_data.describe()
# Out:
#            Order ID     Units Sold     Unit Price      Unit Cost  \
# count  5.000000e+05  500000.000000  500000.000000  500000.000000
# mean   5.501319e+08    4999.136110     266.036748     187.528564
# std    2.599605e+08    2884.023907     216.937600     175.623982
# min    1.000029e+08       1.000000       9.330000       6.920000
# 25%    3.251814e+08    2502.000000      81.730000      56.670000
# 50%    5.491843e+08    4999.000000     154.060000      97.440000
# 75%    7.756291e+08    7497.000000     421.890000     263.330000
# max    9.999995e+08   10000.000000     668.270000     524.960000
#
#        Total Revenue    Total Cost  Total Profit
# count   5.000000e+05  5.000000e+05  5.000000e+05
# mean    1.330096e+06  9.376163e+05  3.924800e+05
# std     1.468090e+06  1.148684e+06  3.787517e+05
# min     9.330000e+00  6.920000e+00  2.410000e+00
# 25%     2.783059e+05  1.620597e+05  9.538506e+04
# 50%     7.862426e+05  4.677120e+05  2.817492e+05
# ...

# %%
financial_data.isna().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
financial_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 14 columns):
# Region            500000 non-null object
# Country           500000 non-null object
# Item Type         500000 non-null object
# Sales Channel     500000 non-null object
# Order Priority    500000 non-null object
# Order Date        500000 non-null object
# Order ID          500000 non-null int64
# Ship Date         500000 non-null object
# Units Sold        500000 non-null int64
# Unit Price        500000 non-null float64
# Unit Cost         500000 non-null float64
# Total Revenue     500000 non-null float64
# Total Cost        500000 non-null float64
# Total Profit      500000 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 53.4+ MB

# %%
financial_data.nunique()
# Out:
# Region                 7
# Country              185
# Item Type             12
# Sales Channel          2
# Order Priority         4
# Order Date          2766
# Order ID          500000
# Ship Date           2816
# Units Sold         10000
# Unit Price            12
# Unit Cost             12
# Total Revenue     118520
# Total Cost        118360
# Total Profit      118404
# dtype: int64

# %%
financial_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 14 columns):
# Region            500000 non-null object
# Country           500000 non-null object
# Item Type         500000 non-null object
# Sales Channel     500000 non-null object
# Order Priority    500000 non-null object
# Order Date        500000 non-null object
# Order ID          500000 non-null int64
# Ship Date         500000 non-null object
# Units Sold        500000 non-null int64
# Unit Price        500000 non-null float64
# Unit Cost         500000 non-null float64
# Total Revenue     500000 non-null float64
# Total Cost        500000 non-null float64
# Total Profit      500000 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 53.4+ MB

# %%
financial_data["Sales Channel"].unique()
# Out:
# array(['Offline', 'Online'], dtype=object)

# %%
financial_data["Region"].unique()
# Out:
# array(['Sub-Saharan Africa', 'Middle East and North Africa',
#        'Australia and Oceania', 'Europe', 'Asia',
#        'Central America and the Caribbean', 'North America'], dtype=object)

# %%
financial_data["Item Type"].unique()
# Out:
# array(['Fruits', 'Clothes', 'Meat', 'Beverages', 'Office Supplies',
#        'Cosmetics', 'Snacks', 'Personal Care', 'Household', 'Vegetables',
#        'Baby Food', 'Cereal'], dtype=object)

# %%
financial_data["Country"].unique()
# Out:
# array(['South Africa', 'Morocco', 'Papua New Guinea', 'Djibouti',
#        'Slovakia', 'Sri Lanka', 'Seychelles ', 'Tanzania', 'Ghana',
#        'Taiwan', 'Algeria', 'Singapore', 'Vietnam', 'Uganda', 'Zimbabwe',
#        'Ethiopia', 'France', 'The Bahamas', 'Haiti', 'Nicaragua',
#        'Turkmenistan', 'United Kingdom', 'Dominican Republic', 'China',
#        'Kuwait', 'United Arab Emirates', 'Estonia', 'Malaysia', 'Vanuatu',
#        'India', 'Samoa ', 'Kazakhstan', 'Czech Republic', 'Belgium',
#        'Finland', 'Oman', 'Dominica', 'Serbia', 'Sao Tome and Principe',
#        'Brunei', 'Israel', 'Solomon Islands', 'Togo', 'Mauritius ',
#        'Canada', 'Lebanon', 'South Korea', 'Indonesia',
#        'Antigua and Barbuda ', 'Tunisia ', 'Thailand', 'Nepal',
#        'Montenegro', 'Greece', 'Monaco', 'Albania', 'Saint Lucia',
#        'Italy', 'Switzerland', 'Netherlands', 'Sweden', 'Burundi',
#        'Iceland', 'Rwanda', 'Japan', 'Romania', 'Belize', 'Egypt',
# ...

# %%
financial_data["Country"].count()
# Out:
# 500000

# %%
financial_data["Order Priority"].unique()
# Out:
# array(['M', 'H', 'L', 'C'], dtype=object)

# %%
#Total sum of unit sold
financial_data["Units Sold"].sum()
# Out:
# 2499568055

# %%
#Highest unit sold
financial_data["Units Sold"].max()
# Out:
# 10000

# %%
#Total Revenue
financial_data["Total Revenue"].sum()
# Out:
# 665048154990.8003

# %%
#Total Revenue
financial_data["Total Profit"].sum()
# Out:
# 196239982294.22006

# %%
#Profit for each region
Region_profit = financial_data.groupby("Region").agg({"Total Profit": 'sum'})
Region_profit
# Out:
#                                    Total Profit
# Region
# Asia                               2.859312e+10
# Australia and Oceania              1.593599e+10
# Central America and the Caribbean  2.124888e+10
# Europe                             5.062910e+10
# Middle East and North Africa       2.435939e+10
# North America                      4.272509e+09
# Sub-Saharan Africa                 5.120098e+10

# %%
#Total amount of unit sold by each region
Region_unit = financial_data.groupby("Region").agg({"Units Sold": 'sum'})
Region_unit
# Out:
#                                    Units Sold
# Region
# Asia                                364122959
# Australia and Oceania               202896949
# Central America and the Caribbean   269684393
# Europe                              646416168
# Middle East and North Africa        310359376
# North America                        54235843
# Sub-Saharan Africa                  651852367

# %%
#Profit for each country
Region_country = financial_data.groupby("Country").agg({"Total Profit": 'sum'}, sort = "True")
Region_country
# Out:
#               Total Profit
# Country
# Afghanistan   1.043572e+09
# Albania       1.063526e+09
# Algeria       1.069623e+09
# Andorra       1.017539e+09
# Angola        1.044508e+09
# ...                    ...
# Vatican City  1.040825e+09
# Vietnam       1.045856e+09
# Yemen         1.090429e+09
# Zambia        1.045330e+09
# Zimbabwe      1.026861e+09
#
# [185 rows x 1 columns]

# %%
Region_country.tail().plot()

# %%
Region_country.iloc[[50,30,27], :]
# Out:
#                                 Total Profit
# Country
# Federated States of Micronesia  1.096110e+09
# China                           1.094581e+09
# Cape Verde                      1.090304e+09

# %%
Region_country.loc[:,["Total Profit"]]
# Out:
#               Total Profit
# Country
# Afghanistan   1.043572e+09
# Albania       1.063526e+09
# Algeria       1.069623e+09
# Andorra       1.017539e+09
# Angola        1.044508e+09
# ...                    ...
# Vatican City  1.040825e+09
# Vietnam       1.045856e+09
# Yemen         1.090429e+09
# Zambia        1.045330e+09
# Zimbabwe      1.026861e+09
#
# [185 rows x 1 columns]

# %%
financial_data
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
#unit sold by items types 
item_total_unit = financial_data.groupby("Item Type").agg({"Units Sold": 'sum'})
item_total_unit
# Out:
#                  Units Sold
# Item Type
# Baby Food         207323669
# Beverages         208722688
# Cereal            208255383
# Clothes           208771337
# Cosmetics         208582024
# Fruits            207457548
# Household         208290108
# Meat              208633540
# Office Supplies   207697272
# Personal Care     209288730
# Snacks            208654607
# Vegetables        207891149

# %% [markdown]
# DATA ANALYSIS VISUALISATION

# %%
plt.figure(figsize=(8,8))
plt.pie(x=[376,166], labels = ["offline", "online"], autopct= "%1.0f%%", colors=['g','y'],labeldistance=0.7,pctdistance=0.5, data = financial_data)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d137f08ac8>,
# ...
#  [Text(-0.4002099976398921, 0.5743099840583284, 'offline'),
#   Text(0.4002100514106717, -0.5743099465879618, 'online')],
#  [Text(-0.2858642840284944, 0.4102214171845203, '69%'),
#   Text(0.2858643224361941, -0.4102213904199727, '31%')])

# %%
financial_data
# Out:
#                               Region           Country        Item Type  \
# 0                 Sub-Saharan Africa      South Africa           Fruits
# 1       Middle East and North Africa           Morocco          Clothes
# 2              Australia and Oceania  Papua New Guinea             Meat
# 3                 Sub-Saharan Africa          Djibouti          Clothes
# 4                             Europe          Slovakia        Beverages
# ...                              ...               ...              ...
# 499995                          Asia           Myanmar           Fruits
# 499996         Australia and Oceania       New Zealand  Office Supplies
# 499997                        Europe         Lithuania           Snacks
# 499998                          Asia          Malaysia        Beverages
# 499999                        Europe          Slovakia        Household
#
#        Sales Channel Order Priority  Order Date   Order ID   Ship Date  \
# ...

# %%
Top_country_profit = financial_data.groupby("Country").agg({"Total Profit":'sum'}).head().plot()
plt.title("Top countries Profit")
# Out:
# Text(0.5, 1.0, 'Top countries Profit')

# %%
#profit in order of priority
sns.lineplot(y = "Total Profit",x = "Order Priority", palette ="summer", size_order = 14, legend="brief", data =financial_data)
